# %%
import sys
import pandas as pd
import numpy as np
from multi_blade import MultiBlade

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# ## English Annotations (Audrey)

# %%
blade_en = MultiBlade(
   model_path = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20",
    source_path="/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/translated/df_1.parquet",
    lang = "EN",
    blade_state_path='/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/multi_blade_state_EN_trained.pkl'
)

# %%
blade_en.df_docs[blade_en.df_docs.human_labeled==True]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                lemmas_x_x  \
# ...

# %% [markdown]
# ## Spanish Annotations (Valerie)

# %%
blade_es = MultiBlade(
   model_path = "/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20",
    source_path="/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/source/corpus_rosie/passages/translated/df_1.parquet",
    lang = "ES",
    blade_state_path='/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/multi_blade_state_ES_trained.pkl'
)

# %%
blade_es.df_docs[blade_es.df_docs.human_labeled==True]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                        lemmas_x_x  \
# 0                                                                                                                                                                                                                                                causas interno oído contener célula_pilosa diminuto terminación_nervioso transformar sonido señal_eléctrico nervio señal cerebro
# ...

# %%
df = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_ES.csv")
df[df.human_labeled==True]
# Out:
# /tmp/ipykernel_3146054/1555556115.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_ES.csv")
#                                                                                                                                                                                                                                                                                                                                                                        lemmas_x_x  \
# ...

# %% [markdown]
# ## Second Evaluation (Karla)

# %%
def get_balanced_sample(path, size=0.6):
    # Read the annotations
    df = pd.read_csv(path)
    df = df[df.human_labeled == True]
    sixty_percent_size = int(len(df) * size)

    # Split the dataframe based on labels
    #positive_df = df[df['label'] == 1.0]
    #negative_df = df[df['label'] == 0.0]

    # Determine the number of samples needed from each label to maintain balance
    n_samples_per_label = int(sixty_percent_size // 2)

    #positive_sample = positive_df.sample(n=n_samples_per_label, random_state=1)
    #negative_sample = negative_df.sample(n=n_samples_per_label, random_state=1)

    # Combine the sampled dataframes into one balanced dataframe
    #balanced_sample = pd.concat([positive_sample, negative_sample])

    # Shuffle the combined dataframe
    #balanced_sample = balanced_sample.sample(frac=1, random_state=1).reset_index(drop=True)
    
    sample = df.sample(n=sixty_percent_size, random_state=1)

    return sample

# %%
df_en = get_balanced_sample("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_EN.csv", size=0.48366013071895425)
df_es = get_balanced_sample("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/data/models/filtering/rosie_1_20/df_docs_updated_ES.csv", size=1)
# Out:
# /tmp/ipykernel_3146054/534239435.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# /tmp/ipykernel_3146054/534239435.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
len(blade_es.df_docs[blade_es.df_docs.human_labeled==True])*100/len(blade_en.df_docs[blade_en.df_docs.human_labeled==True])*0.01
# Out:
# 0.48366013071895425

# %%
print(len(df_en))
print(len(df_es))
print(len(blade_es.df_docs[blade_es.df_docs.human_labeled==True]))
# Out:
# 74
# 74
# 74

# %%
combined_df = pd.concat([df_en, df_es]).sample(frac=1, random_state=1).reset_index(drop=True)
len(combined_df)
# Out:
# 148
