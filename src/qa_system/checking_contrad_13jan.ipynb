# %%
import pandas as pd

# %%
topic2 = pd.read_csv("/export/usuarios_ml4ds/lbartolome/Repos/umd/LinQAForge/src/qa_system/df_info_topic_2.csv")
for el_id, el in topic1[topic1['contradiction'] == "yes"].iterrows():
    print("#####################")
    print(f"PASSAGE: {el['passage']}")
    print(f"QUESTION: {el['questions']}")
    print(f"QUERIES: {el['queries']}")
    print(f"ENTITIES: {el['entities']}")
    print(f"ANSWERS: {el['answers']}")
    print(f"PASSAGE ES: {el['text_passages_used']}")
    print(f"FULL TEXT ES: {el['text_passages_used']}")
    print(f"CONTRADICTION REASON: {el['contradiction_reason']}")
    print("\n")
    #print(f"CONTRADICTION TYPE: {el['contradiction_type']}")
# Out:
# #####################
# PASSAGE: Causes of vitamin B12 deficiency include:\n- Not enough vitamin B12 in diet (rare, except with a strict vegetarian diet)\n- Diseases that cause malabsorption (for example, celiac disease and Crohn disease)\n- Lack of intrinsic factor, a protein that helps the intestine absorb vitamin B12\n- Above normal heat production (for example, with hyperthyroidism)\n- Pregnancy.
# QUESTION: Is pregnancy a possible cause of vitamin B12 deficiency?
# QUERIES: ['Vitamin B12 deficiency causes', 'Pregnancy and vitamin B12 deficiency', 'Effects of pregnancy on vitamin B12 levels']
# ENTITIES: ['B12']
# ...
